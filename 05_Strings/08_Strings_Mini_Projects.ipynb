# %% [markdown]
# # Strings Mini Projects
#
# ## Topic
#
# Real-World String Projects
#
# ## Description
#
# This notebook contains beginner-friendly mini projects using Python strings. These projects improve problem-solving skills and demonstrate practical applications of string methods.
#
# **Author:** Shilpa

# %% [markdown]
# ## Project 1 - Password Strength Checker

# %%
password = input("Enter your password: ")

if len(password) >= 8:
    print("Strong Password")
else:
    print("Weak Password")
# Out:
# Enter your password:  Python123
# Strong Password

# %% [markdown]
# ## Project 2 - Email Validator

# %%
email = input("Enter email: ")

if "@" in email and "." in email:
    print("Valid Email")
else:
    print("Invalid Email")
# Out:
# Enter email:  abc@gmail.com
# Valid Email

# %% [markdown]
# ## Project 3 - Username Validator

# %%
username = input("Enter username: ")

if username.isalnum():
    print("Valid Username")
else:
    print("Username should contain only letters and numbers.")
# Out:
# Enter username:  abc123
# Valid Username

# %% [markdown]
# ## Project 4 - Word Counter

# %%
sentence = input("Enter a sentence: ")

words = sentence.split()

print("Total Words:", len(words))
# Out:
# Enter a sentence:  I am a data analyst
# Total Words: 5

# %% [markdown]
# ## Project 5 - Character Frequency Analyzer

# %%
text = input("Enter a string: ")

for ch in sorted(set(text)):
    print(ch, ":", text.count(ch))
# Out:
# Enter a string:  Python
# P : 1
# h : 1
# n : 1
# o : 1
# t : 1
# y : 1

# %% [markdown]
# ## Project 6 - Name Formatter

# %%
name = input("Enter your full name: ")

print(name.title())
# Out:
# Enter your full name:  Shilpa Bele
# Shilpa Bele

# %% [markdown]
# ## Project 7 - Text Formatter

# %%
text = input("Enter text: ")

print("Uppercase :", text.upper())
print("Lowercase :", text.lower())
print("Title Case:", text.title())
# Out:
# Enter text:  PYTHON
# Uppercase : PYTHON
# Lowercase : python
# Title Case: Python

# %% [markdown]
# ## Project 8 - Sentence Statistics

# %%
sentence = input("Enter a sentence: ")

print("Characters:", len(sentence))
print("Words:", len(sentence.split()))
print("Vowels:", sum(1 for ch in sentence.lower() if ch in "aeiou"))
# Out:
# Enter a sentence:  I am in pune
# Characters: 12
# Words: 4
# Vowels: 5

# %% [markdown]
# ## Project 9 - Simple Text Encryptor

# %%
text = input("Enter text: ")

encrypted = ""

for ch in text:
    encrypted += chr(ord(ch) + 1)

print("Encrypted Text:", encrypted)
# Out:
# Enter text:  notebook
# Encrypted Text: opufcppl

# %% [markdown]
# ## Project 10 - Contact Search

# %%
contacts = ["Rahul", "Shilpa", "Amit", "Neha"]

name = input("Search name: ")

if name in contacts:
    print("Contact Found")
else:
    print("Contact Not Found")
# Out:
# Search name:  Shilpa
# Contact Found
