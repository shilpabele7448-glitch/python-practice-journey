# %% [markdown]
# # Operators in Python
#
# ## Topic
# Operators
#
# ## Description
# This notebook explains different types of operators in Python with examples.
#
# **Author:** Shilpa
#
# ---
#
# ## Why is this Topic Important?
#
# Operators help us perform calculations, compare values, assign data, and make decisions in Python. Almost every Python program uses operators.
#
# ---
#
# ## What are Operators?
#
# Operators are symbols that perform operations on variables and values.
#
# For example:
#
# ```python
# 5 + 3
# ```
#
# Here, **+** is an operator that adds two numbers.

# %% [markdown]
# ## Types of Operators
#
# 1. Arithmetic Operators
# 2. Comparison Operators
# 3. Assignment Operators
# 4. Logical Operators
# 5. Membership Operators
# 6. Identity Operators

# %%
a = 10
b = 3

print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
print("Division:", a / b)
print("Floor Division:", a // b)
print("Modulus:", a % b)
print("Power:", a ** b)
# Out:
# Addition: 13
# Subtraction: 7
# Multiplication: 30
# Division: 3.3333333333333335
# Floor Division: 3
# Modulus: 1
# Power: 1000

# %% [markdown]
# ## Arithmetic Operators
#
# Used for mathematical calculations.
#
# | Operator | Meaning |
# |----------|---------|
# | + | Addition |
# | - | Subtraction |
# | * | Multiplication |
# | / | Division |
# | // | Floor Division |
# | % | Modulus (Remainder) |
# | ** | Power |

# %%
a = 10
b = 20

print(a == b)
print(a != b)
print(a > b)
print(a < b)
print(a >= b)
print(a <= b)
# Out:
# False
# True
# False
# True
# False
# True

# %% [markdown]
# ## Comparison Operators
#
# Comparison operators compare two values and return either True or False.

# %%
x = 10

x += 5
print(x)

x -= 2
print(x)

x *= 3
print(x)
# Out:
# 15
# 13
# 39

# %% [markdown]
# ## Assignment Operators
#
# Assignment operators assign values to variables.
#
# Examples:
# =, +=, -=, *=, /=, //=, %=, **=

# %%
a = True
b = False

print(a and b)
print(a or b)
print(not a)
# Out:
# False
# True
# False

# %% [markdown]
# ## Logical Operators
#
# Logical operators are used to combine conditions.
#
# and → Both conditions must be True.
#
# or → At least one condition must be True.
#
# not → Reverses the result.

# %%
fruits = ["Apple", "Banana", "Mango"]

print("Apple" in fruits)
print("Orange" in fruits)
print("Orange" not in fruits)
# Out:
# True
# False
# True

# %%
x = [1, 2, 3]
y = x
z = [1, 2, 3]

print(x is y)
print(x is z)
print(x is not z)
# Out:
# True
# False
# True

# %% [markdown]
# ## Common Mistakes
#
# ❌ Using = instead of ==
#
# Wrong:
#
# ```python
# if age = 18:
# ```
#
# Correct:
#
# ```python
# if age == 18:
# ```
#
# Remember:
#
# =  → Assigns a value
#
# == → Compares two values

# %% [markdown]
# ## Real-Life Example
#
# Imagine you are shopping.
#
# If a T-shirt costs ₹500 and you buy 2:
#
# 500 × 2 = 1000
#
# Here, × (multiplication) is an operator.
#
# If you want to check whether your age is greater than 18:
#
# age > 18
#
# Here, > (greater than) is a comparison operator.

# %% [markdown]
# ## What I Learned
#
# - What are Operators
# - Arithmetic Operators
# - Comparison Operators
# - Assignment Operators
# - Logical Operators
# - Membership Operators
# - Identity Operators

# %%
n1=23
n2=15
res=n1+n2
res
# Out:
# 38

# %%
num1=int(input("Enter any number"))
num2=int(input("Enter any number"))
addition=num1+num2
print(f"addition of {num1} and {num2} is {addition}")
# Out:
# Enter any number 56
# Enter any number 73
# addition of 56 and 73 is 129

# %%
Sameer=int(input("Sameer brought flowers"))
Sulabha=int(input("Sulabha brought flowers"))
flowers=Sameer+Sulabha
print(f"They brought {flowers} flowers together.")
# Out:
# Sameer brought flowers 5
# Sulabha brought flowers 4
# They brought 9 flowers together.

# %%
n1=23
n2=15
res=n1-n2
res
# Out:
# 8

# %%
Aai=int(input("Aai made chapatees"))
Dada=int(input("gave chapatees to dada in his tiffin"))
chapatees=Aai-Dada
print(f"Only {chapatees} chapatees were left.")
# Out:
# Aai made chapatees 34
# gave chapatees to dada in his tiffin 22
# Only 12 chapatees were left.

# %%
rad=float(input("Enter radius"))
area=3.14*rad*rad
print("Area of circle is",area)
# Out:
# Enter radius 2.5
# Area of circle is 19.625

# %%
rad=int(input("Enter radius"))
diameter=2*rad
print("diameter of the circle is",diameter)
# Out:
# Enter radius 5
# diameter of the circle is 10

# %%
n1=5
sqr=n1**2
print(f"The square of 5 is {sqr}")
# Out:
# The square of 5 is 25

# %%
num=int(input("enter number here"))
sr=num**0.5
print("square root of the given number is", sr)
# Out:
# enter number here 144
# square root of the given number is 12.0

# %%
num1=int(input("Enter any number"))
num2=int(input("Enter any number"))
remainder=num1%num2
print("remainder",remainder)
# Out:
# Enter any number 5
# Enter any number 3
# remainder 2

# %%
num1=int(input("Enter any number"))
num2=int(input("Enter any number"))
quotient=num1//num2
print("Result", quotient)
# Out:
# Enter any number 5
# Enter any number 3
# Result 1

# %%
num1=int(input("Enter any number"))
num2=int(input("Enter any number"))
power=num1**num2
print("Result", power)
# Out:
# Enter any number 4
# Enter any number 2
# Result 16

# %%
(125)**(1/3)
# Out:
# 5.0
