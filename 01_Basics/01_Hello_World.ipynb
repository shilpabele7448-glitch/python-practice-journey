# %% [markdown]
# # Hello World
#
# ## Topic
# Hello World
#
# ## Description
# This notebook demonstrates the first Python program.
#
# **Author:** Shilpa

# %%
print("Hello, World!")
# Out:
# Hello, World!
