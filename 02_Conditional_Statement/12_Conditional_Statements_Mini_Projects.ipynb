# %% [markdown]
# # Conditional Statements - Mini Projects
#
# ## Topic
#
# Conditional Statements Mini Projects
#
# ## Description
#
# This notebook contains beginner-friendly mini projects based on Python conditional statements. These projects help in understanding how decision-making works in real-world applications.
#
# **Author:** Shilpa

# %% [markdown]
# # Mini Project 1 - Student Grade System

# %%
marks = int(input("Enter your marks: "))

if marks >= 90:
    print("Grade A")
elif marks >= 75:
    print("Grade B")
elif marks >= 50:
    print("Grade C")
elif marks >= 35:
    print("Grade D")
else:
    print("Fail")
# Out:
# Enter your marks:  84
# Grade B

# %% [markdown]
# # Mini Project 2 - Voting Eligibility Checker

# %%
age = int(input("Enter your age: "))

if age >= 18:
    print("You are eligible to vote.")
else:
    print("You are not eligible to vote.")
# Out:
# Enter your age:  22
# You are eligible to vote.

# %% [markdown]
# # Mini Project 3 - ATM Menu

# %%
print("1. Check Balance")
print("2. Deposit")
print("3. Withdraw")
print("4. Exit")

choice = int(input("Enter your choice: "))

if choice == 1:
    print("Balance: ₹25,000")
elif choice == 2:
    print("Deposit Selected")
elif choice == 3:
    print("Withdraw Selected")
elif choice == 4:
    print("Thank You")
else:
    print("Invalid Choice")
# Out:
# 1. Check Balance
# 2. Deposit
# 3. Withdraw
# 4. Exit
# Enter your choice:  1
# Balance: ₹25,000

# %% [markdown]
# # Mini Project 4 - Login System

# %%
username = input("Enter username: ")
password = input("Enter password: ")

if username == "admin" and password == "python123":
    print("Login Successful")
else:
    print("Invalid Username or Password")
# Out:
# Enter username:  admin
# Enter password:  python123
# Login Successful

# %% [markdown]
# # Mini Project 5 - Even or Odd Checker

# %%
number = int(input("Enter a number: "))

if number % 2 == 0:
    print("Even Number")
else:
    print("Odd Number")
# Out:
# Enter a number:  6
# Even Number

# %% [markdown]
# # Mini Project 6 - Largest of Two Numbers

# %%
num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))

if num1 > num2:
    print("Largest Number:", num1)
else:
    print("Largest Number:", num2)
# Out:
# Enter first number:  74
# Enter second number:  72
# Largest Number: 74

# %% [markdown]
# # Mini Project 7 - Electricity Bill Calculator

# %%
units = int(input("Enter electricity units: "))

if units <= 100:
    bill = units * 5
elif units <= 200:
    bill = units * 7
else:
    bill = units * 10

print("Electricity Bill = ₹", bill)
# Out:
# Enter electricity units:  40
# Electricity Bill = ₹ 200

# %% [markdown]
# # Mini Project 8 - BMI Category Checker

# %%
weight = float(input("Enter weight (kg): "))
height = float(input("Enter height (m): "))

bmi = weight / (height ** 2)

print("BMI =", round(bmi, 2))

if bmi < 18.5:
    print("Underweight")
elif bmi < 25:
    print("Normal Weight")
elif bmi < 30:
    print("Overweight")
else:
    print("Obese")
# Out:
# Enter weight (kg):  46
# Enter height (m):  159
# BMI = 0.0
# Underweight

# %% [markdown]
# # Mini Project 9 - Shopping Discount Calculator

# %%
amount = float(input("Enter shopping amount: "))

if amount >= 5000:
    discount = amount * 0.20
elif amount >= 3000:
    discount = amount * 0.10
else:
    discount = 0

final_amount = amount - discount

print("Discount = ₹", discount)
print("Final Amount = ₹", final_amount)
# Out:
# Enter shopping amount:  4000
# Discount = ₹ 400.0
# Final Amount = ₹ 3600.0

# %% [markdown]
# # Mini Project 10 - Simple Calculator

# %%
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

operator = input("Enter operator (+, -, *, /): ")

if operator == "+":
    print("Result =", num1 + num2)
elif operator == "-":
    print("Result =", num1 - num2)
elif operator == "*":
    print("Result =", num1 * num2)
elif operator == "/":
    if num2 != 0:
        print("Result =", num1 / num2)
    else:
        print("Cannot divide by zero.")
else:
    print("Invalid Operator")
# Out:
# Enter first number:  4
# Enter second number:  2
# Enter operator (+, -, *, /):  *
# Result = 8.0

# %% [markdown]
# # Conclusion
#
# These mini projects helped me understand how conditional statements are used to make decisions in Python. They also showed how conditions can be applied to solve simple real-world problems.
#
# Thank you for exploring this notebook!
